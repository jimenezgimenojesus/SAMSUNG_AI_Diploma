# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as la

# %%
xi = np.array([-2, -1, 0, 1, 2, 3, 4, 5])
yi = np.array([-2, -1, 1.5, -2, 2, 1, 3.5, 3])

plt.figure(figsize=(4, 4))
plt.xlim(-2.5, 5.5)
plt.ylim(-4, 14)
plt.plot(xi, yi, '*g')
plt.show()

# %%
# Error cometido

error = np.sum((yi - y_gorrito)**2)
print('Éste es el error cuadrático:', error)
# Out:
# Éste es el error cuadrático: 49.654829691056804

# %%
# Ajuste lineal

a, b = 0.723, -0.355

y_gorrito = a * xi + b


plt.figure(figsize=(4, 4))
plt.xlim(-2.5, 5.5)
plt.ylim(-4, 6)
plt.plot(xi, yi, '*g', xi, y_gorrito, 'or', t, a*t+b, 'r')
plt.show()

# Error cometido

error = np.sum((yi - y_gorrito)**2)
print('Éste es el error cuadrático:', error)
# Out:
# Éste es el error cuadrático: 11.577979999999998

# %%
# Ajuste exponencial del tipo y = a*e^(bx)

a, b, c = 0.56, 0.45, -1

y_gorrito = a * np.exp(b * xi) + c


plt.figure(figsize=(4, 4))
plt.xlim(-2.5, 5.5)
plt.ylim(-2.5, 5)
plt.plot(xi, yi, '*g', xi, y_gorrito, 'or', t, a*np.exp(b*t)+c, 'r')
plt.show()

# Error cometido

error = np.sum((yi - y_gorrito)**2)
print('Éste es el error cuadrático:', error)
# Out:
# Éste es el error cuadrático: 14.545989780323282

# %%
# Método del Gradiente Descendiente (ajuste lineal)

xbarra = np.array([[2], [2]])
alpha = 0.005
gradiente = np.array([[np.sum(2 * (yi - (xbarra[0, 0]*xi + xbarra[1,0]))*(-xi))],
                       [np.sum(2 * (yi - (xbarra[0, 0]*xi + xbarra[1,0])) * (-1))]])

# Tener cuidado con CÓMO SE PONEN los valores, si por columna o fila [[]]
xbarra = xbarra - alpha * gradiente

# Error cometido
error = np.sum((yi - (xbarra[0, 0]*xi + xbarra[1,0]))**2)
# El error tiene que ser MÁS PEQUEÑO después de la primera iteración
print('Éste es el error cuadrático:', error)
print(xbarra, end='\n\n')

for i in range (100):
    gradiente = np.array([[np.sum(2 * (yi - (xbarra[0, 0]*xi + xbarra[1,0]))*(-xi))],
                       [np.sum(2 * (yi - (xbarra[0, 0]*xi + xbarra[1,0])) * (-1))]])
    xbarra = xbarra - alpha * gradiente
    
    # Error cometido
    error = np.sum((yi - (xbarra[0, 0]*xi + xbarra[1,0]))**2)
    # El error tiene que ser MÁS PEQUEÑO después de la primera iteración
    print('Éste es el error cuadrático:', error)

print(); print(xbarra)
# Out:
# Éste es el error cuadrático: 57.52279999999999
# [[0.95]
#  [1.66]]
#
# Éste es el error cuadrático: 32.39216576
# Éste es el error cuadrático: 27.379619723264
# Éste es el error cuadrático: 25.33278965173944
# Éste es el error cuadrático: 23.840644629806597
# Éste es el error cuadrático: 22.55189732556143
# Éste es el error cuadrático: 21.404353425048374
# Éste es el error cuadrático: 20.377551869379047
# Éste es el error cuadrático: 19.45808770956125
# Éste es el error cuadrático: 18.634642449155812
# Éste es el error cuadrático: 17.897175241100037
# Éste es el error cuadrático: 17.23670698562715
# Éste es el error cuadrático: 16.64519795548778
# Éste es el error cuadrático: 16.115448108455308
# Éste es el error cuadrático: 15.641009191712351
# Éste es el error cuadrático: 15.216106216534055
# Éste es el error cuadrático: 14.835567158729054
# Éste es el error cuadrático: 14.494760002788663
# Éste es el error cuadrático: 14.18953635975214
# Éste es el error cuadrático: 13.91618097197714
# Éste es el error cuadrático: 13.671366490103301
# Éste es el error cuadrático: 13.452112971732957
# Éste es el error cuadrático: 13.25575160883553
# Éste es el error cuadrático: 13.079892242356376
# Éste es el error cuadrático: 12.92239426860985
# Éste es el error cuadrático: 12.781340583322063
# Éste es el error cuadrático: 12.655014246163674
# Éste es el error cuadrático: 12.541877581727753
# Éste es el error cuadrático: 12.440553462564555
# Éste es el error cuadrático: 12.349808546445765
# Éste es el error cuadrático: 12.26853826381796
# Éste es el error cuadrático: 12.19575337270894
# Éste es el error cuadrático: 12.130567917429874
# Éste es el error cuadrático: 12.072188444503627
# Éste es el error cuadrático: 12.019904344552858
# Éste es el error cuadrático: 11.973079202587037
# Éste es el error cuadrático: 11.931143051401797
# Éste es el error cuadrático: 11.893585433797242
# Éste es el error cuadrático: 11.859949189166706
# Éste es el error cuadrático: 11.82982488882482
# Éste es el error cuadrático: 11.802845852340342
# Éste es el error cuadrático: 11.778683684211284
# Éste es el error cuadrático: 11.757044276553685
# Éste es el error cuadrático: 11.737664229147734
# Éste es el error cuadrático: 11.720307643265166
# Éste es el error cuadrático: 11.70476325025164
# Éste es el error cuadrático: 11.690841839912432
# Éste es el error cuadrático: 11.678373957399165
# Éste es el error cuadrático: 11.667207840563519
# Éste es el error cuadrático: 11.65720757267082
# Éste es el error cuadrático: 11.648251427987972
# Éste es el error cuadrático: 11.640230390107702
# Éste es el error cuadrático: 11.633046824973926
# Éste es el error cuadrático: 11.626613292455891
# Éste es el error cuadrático: 11.620851482005245
# Éste es el error cuadrático: 11.615691259440725
# Éste es el error cuadrático: 11.611069813257537
# Éste es el error cuadrático: 11.6069308900702
# Éste es el error cuadrático: 11.603224109882433
# Éste es el error cuadrático: 11.599904352849384
# Éste es el error cuadrático: 11.596931210067712
# Éste es el error cuadrático: 11.594268491708457
# Éste es el error cuadrático: 11.591883786505445
# Éste es el error cuadrático: 11.589748067237391
# Éste es el error cuadrático: 11.587835337401366
# Éste es el error cuadrático: 11.586122314776924
# Éste es el error cuadrático: 11.58458814802918
# Éste es el error cuadrático: 11.583214162901196
# Éste es el error cuadrático: 11.581983634906312
# Éste es el error cuadrático: 11.580881585753556
# Éste es el error cuadrático: 11.579894601028187
# Éste es el error cuadrático: 11.579010666908117
# Éste es el error cuadrático: 11.578219023928707
# Éste es el error cuadrático: 11.577510036015905
# Éste es el error cuadrático: 11.576875073193545
# Éste es el error cuadrático: 11.576306406537181
# Éste es el error cuadrático: 11.575797114095687
# Éste es el error cuadrático: 11.575340996635546
# Éste es el error cuadrático: 11.57493250218228
# Éste es el error cuadrático: 11.574566658440402
# Éste es el error cuadrático: 11.574239012269445
# Éste es el error cuadrático: 11.573945575479222
# Éste es el error cuadrático: 11.573682776284562
# Éste es el error cuadrático: 11.57344741582871
# Éste es el error cuadrático: 11.573236629246004
# Éste es el error cuadrático: 11.573047850790049
# Éste es el error cuadrático: 11.572878782602807
# Éste es el error cuadrático: 11.572727366744505
# Éste es el error cuadrático: 11.572591760143888
# Éste es el error cuadrático: 11.57247031216388
# Éste es el error cuadrático: 11.57236154450965
# Éste es el error cuadrático: 11.572264133234416
# Éste es el error cuadrático: 11.572176892624054
# Éste es el error cuadrático: 11.572098760764288
# Éste es el error cuadrático: 11.572028786614801
# Éste es el error cuadrático: 11.571966118432954
# Éste es el error cuadrático: 11.571909993406136
# Éste es el error cuadrático: 11.571859728366649
# Éste es el error cuadrático: 11.571814711476005
# Éste es el error cuadrático: 11.571774394777483
# Éste es el error cuadrático: 11.571738287526257
#
# [[ 0.71265568]
#  [-0.31400706]]

# %%
# Ajuste lineal

a, b = 0.71265568, -0.31400706

y_gorrito = a * xi + b


plt.figure(figsize=(4, 4))
plt.xlim(-2.5, 5.5)
plt.ylim(-4, 6)
plt.plot(xi, yi, '*g', xi, y_gorrito, 'or', t, a*t+b, 'r')
plt.show()

# Error cometido

error = np.sum((yi - y_gorrito)**2)
print('Éste es el error cuadrático:', error)

# Si quieres utilizar un ALPHA grande (como 0.1), normaliza el vector gradiente (divídelo entre la raíz de la suma de los cuadrados de sus componentes)
# Out:
# Éste es el error cuadrático: 11.571738287156073

# %%
# Método del Gradiente Descendiente (ajsute lineal)

xbarra = np.array([[0.5], [0.4], [-1]])
alpha = 0.01
gradiente = np.array([[np.sum(2 * (yi - (xbarra[0, 0] * np.exp(xbarra[1, 0]*xi)+xbarra[2, 0]))*(-np.exp(xbarra[1,0]*xi)))],
                      [np.sum(2 * (yi - (xbarra[0, 0] * np.exp(xbarra[1, 0]*xi)+xbarra[2, 0]))*(-xbarra[0,0]*np.exp(xbarra[1, 0]*xi)*xi))],
                      [np.sum(2 * (yi - (xbarra[0, 0] * np.exp(xbarra[1, 0]*xi)+xbarra[2, 0]))*(-1))]])

# Tener cuidado con CÓMO SE PONEN los valores, si por columna o fila [[]]
xbarra = xbarra - alpha * gradiente/la.norm(gradiente)

# Error cometido
error = np.sum((yi - (xbarra[0, 0]*np.exp(xbarra[1,0]*xi)+xbarra[2, 0]))**2)
# El error tiene que ser MÁS PEQUEÑO después de la primera iteración
print('Éste es el error cuadrático:', error)
print(xbarra, end='\n\n')

for i in range (1000000):
    gradiente = np.array([[np.sum(2 * (yi - (xbarra[0, 0] * np.exp(xbarra[1, 0]*xi)+xbarra[2, 0]))*(-np.exp(xbarra[1,0]*xi)))],
                          [np.sum(2 * (yi - (xbarra[0, 0] * np.exp(xbarra[1, 0]*xi)+xbarra[2, 0]))*(-xbarra[0,0]*np.exp(xbarra[1, 0]*xi)*xi))],
                          [np.sum(2 * (yi - (xbarra[0, 0] * np.exp(xbarra[1, 0]*xi)+xbarra[2, 0]))*(-1))]])
    
    xbarra = xbarra - alpha * gradiente/la.norm(gradiente)
    
    # Error cometido
    error = np.sum((yi - (xbarra[0, 0]*np.exp(xbarra[1,0]*xi)+xbarra[2, 0]))**2)
    # El error tiene que ser MÁS PEQUEÑO después de la primera iteración
    # print('Éste es el error cuadrático:', error)

print()
print('Éste es el error cuadrático:', error)
print(xbarra)
# Out:
# Éste es el error cuadrático: 15.868154982129724
# [[ 0.50462494]
#  [ 0.4088177 ]
#  [-0.99907369]]
#
#
# Éste es el error cuadrático: 11.749597322745432
# [[ 6.2902933 ]
#  [ 0.0907844 ]
#  [-6.68865564]]

# %%
# Ajuste exponencial del tipo y = a*e^(bx)

a, b, c = 6.2902933, 0.0907844, -6.68865564

y_gorrito = a * np.exp(b * xi) + c

plt.figure(figsize=(4, 4))
plt.xlim(-2.5, 5.5)
plt.ylim(-2.5, 5)
plt.plot(xi, yi, '*g', xi, y_gorrito, 'or', t, a*np.exp(b*t)+c, 'r')
plt.show()

# Error cometido
error = np.sum((yi - (xbarra[0, 0]*np.exp(xbarra[1,0]*xi)+xbarra[2, 0]))**2)
print('Éste es el error cuadrático:', error)
# Out:
# Éste es el error cuadrático: 11.749597322745432

# %%
# Método del Gradiente Descendiente (ajuste lineal)

xi = np.array([0.0, 1.0, 1.5, 2.0, 2.5, 3.0, 6, 6.5])
yi = np.array([0.10, 0.85, 0.99, 0.91, 0.60, 0.12, -0.05, 0.42])

xbarra = np.array([[4.0], [1.0], [1]])
alpha = 0.001
gradiente = np.array([[np.sum(2 * (yi -(xbarra[0, 0]*np.sin(np.exp(xbarra[1,0]*xi))+xbarra[2, 0])) * (- np.sin(xbarra[1,0]*xi)))],
                      [np.sum(2 * (yi -(xbarra[0, 0]*np.sin(np.exp(xbarra[1,0]*xi))+xbarra[2, 0])) * (- xbarra[0,0]*xi*np.cos(xbarra[1,0]*xi)))],
                      [np.sum(2 * (yi -(xbarra[0, 0]*np.sin(np.exp(xbarra[1,0]*xi))+xbarra[2, 0])) * (- 1))]])

# Tener cuidado con CÓMO SE PONEN los valores, si por columna o fila [[]]
xbarra = xbarra - alpha * gradiente/la.norm(gradiente)

# Error cometido
error = np.sum((yi - (xbarra[0, 0]*np.sin(np.exp(xbarra[1,0]*xi))+xbarra[2, 0]))**2)
# El error tiene que ser MÁS PEQUEÑO después de la primera iteración
print('Éste es el error cuadrático:', error)
print(xbarra, end='\n\n')

for i in range (10000):
    gradiente = np.array([[np.sum(2 * (yi -(xbarra[0, 0]*np.sin(np.exp(xbarra[1,0]*xi))+xbarra[2, 0])) * (- np.sin(xbarra[1,0]*xi)))],
                      [np.sum(2 * (yi -(xbarra[0, 0]*np.sin(np.exp(xbarra[1,0]*xi))+xbarra[2, 0])) * (- xbarra[0,0]*xi*np.cos(xbarra[1,0]*xi)))],
                      [np.sum(2 * (yi -(xbarra[0, 0]*np.sin(np.exp(xbarra[1,0]*xi))+xbarra[2, 0])) * (- 1))]])
    
    xbarra = xbarra - alpha * gradiente/la.norm(gradiente)
    
    # Error cometido
    error = np.sum((yi - (xbarra[0, 0]*np.sin(np.exp(xbarra[1,0]*xi))+xbarra[2, 0]))**2)
    # El error tiene que ser MÁS PEQUEÑO después de la primera iteración
    # print('Éste es el error cuadrático:', error)

print()
print('Éste es el error cuadrático:', error)
print(xbarra)
# Out:
# Éste es el error cuadrático: 104.25816932748211
# [[4.00006912]
#  [1.00049061]
#  [0.99913137]]
#
#
# Éste es el error cuadrático: 79.2758698420765
# [[ 3.83594738]
#  [ 1.04642241]
#  [-0.0618583 ]]

# %%
# Ajuste exponencial del tipo y = a*e^(bx)

a, b, c = 4.0, 1, 1

y_gorrito = xbarra[0,0]*np.sin(xbarra[2,0]*xi)+c

plt.figure(figsize=(4, 4))
plt.xlim(-2.5, 5.5)
plt.ylim(-2.5, 5)
plt.plot(xi, yi, '*g', xi, y_gorrito, 'or', t, xbarra[0,0]*np.sin(xbarra[2,0]*t)+c, 'r')
plt.show()

# Error cometido
error = np.sum((yi - (xbarra[0, 0]*np.exp(xbarra[1,0]*xi)+xbarra[2, 0]))**2)
print('Éste es el error cuadrático:', error)
# Out:
# Éste es el error cuadrático: 16092056.570882546
